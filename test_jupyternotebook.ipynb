# %% [markdown]
# ## print out, "Hello, world!"

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# asdfasfasfasfsf

# %%
print(1)
print('wtf')
# Out:
# 1
# wtf

# %% [markdown]
# sdfsdsdas
# s
# asf
# saf
# as
# as
# fas
# f
# s
#
#
#
# sdf
# sf
# sd
# f![pub_fw7_11.png](attachment:pub_fw7_11.png)

# %%
print('1,2,3')
# Out:
# 1,2,3

# %%
a=10
b=20
print('%d'%(a+b))
print('done!!!')
# Out:
# 30
# done!!!
